# %% [markdown]
# <a href="https://colab.research.google.com/github/Sbilalahmad/AI_ML_mentorship/blob/main/notebooks/NLP/NLP2_Indian_Fake_News_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "IFND.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "sonalgarg174/ifnd-dataset",
  file_path,
  pandas_kwargs={"encoding": "latin1"}
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipython-input-3109953727.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'ifnd-dataset' dataset.
# First 5 records:    id                                          Statement  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# ...

# %%
df.head()
# Out:
#    id                                          Statement  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# 3  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 4  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  ELECTION
#
#      Date Label
# 0  Oct-20  TRUE
# 1  Oct-20  TRUE
# 2  Oct-20  TRUE
# 3  Oct-20  TRUE
# 4  Oct-20  TRUE

# %%
df.drop(df[['id','Image','Date']],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Statement    0
# Web          0
# Category     0
# Label        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Label'].value_counts()
# Out:
# Label
# TRUE    37800
# Fake    18911
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
df['Label']=lb.fit_transform(df['Label'])
df
# Out:
#                                                Statement         Web  \
# 0      WHO praises India's Aarogya Setu app, says it ...    DNAINDIA
# 1      In Delhi, Deputy US Secretary of State Stephen...    DNAINDIA
# 2      LAC tensions: China's strategy behind delibera...    DNAINDIA
# 3      India has signed 250 documents on Space cooper...    DNAINDIA
# 4      Tamil Nadu chief minister's mother passes away...    DNAINDIA
# ...                                                  ...         ...
# 56709  Fact Check: This is not Bruce Lee playing ping...  INDIATODAY
# 56710  Fact Check: Did Japan construct this bridge in...  INDIATODAY
# 56711  Fact Check: Viral video of Mexico earthquake i...  INDIATODAY
# 56712  Fact Check: Ballet performance by Chinese coup...  INDIATODAY
# 56713  Fact Check: Is this little boy crossing into J...  INDIATODAY
#
#          Category  Label
# 0        COVID-19      1
# 1        VIOLENCE      1
# 2          TERROR      1
# 3        COVID-19      1
# ...

# %%
df['Web'].value_counts()
# Out:
# Web
# TRIBUNEINDIA        11832
# AUGMENT             11320
# THEPRINT             8582
# THESTATESMAN         7202
# THESTATEMAN          4048
# INDIANEXPRESS        3983
# NEWSMOBILE           2420
# INDIATODAY           1698
# BOOMLIVE              806
# CNN                   778
# NEWSMETER             572
# ONEINDIA              549
# BSMEDIA               449
# TEEKHIMIRCHI          387
# FACTCRESCENDO         272
# AFP                   267
# TIMESNOW              238
# THELOGICALINDIAN      221
# DIGITEYE              175
# FACTLY                174
# THELOGICALINDIA       173
# FACTCHECKER           163
# DAPAAN                136
# DNAINDIA              121
# ALT                    59
# WAHSARKAR              42
# ENGLISHTRIBUNE         21
# INDUSTANTIMES          15
# NDTV                    8
# Name: count, dtype: int64

# %%
df['Category'].groupby(df['Label']).value_counts()
# Out:
# Label  Category
# 0      VIOLENCE      4963
#        MISLEADING    4059
#        GOVERNMENT    3604
#        POLITICS      3222
#        COVID-19      2790
#        TRAD           146
#        ELECTION       109
#        MISLEADIND      18
# 1      ELECTION      8287
#        GOVERNMENT    7317
#        COVID-19      5920
#        VIOLENCE      5614
#        POLITICS      5448
#        TERROR        4384
#        TRAD           830
# Name: count, dtype: int64

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
#Superwised Learning models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier
#Unsuperwised Learning models
from sklearn.cluster import KMeans

# %%
models={
    'LogisticRegression':LogisticRegression(),
    'DecisionTreeClassifier':DecisionTreeClassifier(),
    'RandomForestClassifier':RandomForestClassifier(),
    'MultinomialNB':MultinomialNB(),
    'SVC':SVC(),
    'KNeighborsClassifier':KNeighborsClassifier(),
}

# %%
import re
def clean_text(text):
  text=text.lower()
  text=re.sub('[!@#$%^&*({})|:">?</.,]','',text)
  text=word_tokenize(text)
  text=[word for word in text if word not in stopwords.words('english')]
  text=[PorterStemmer().stem(word) for word in text]
  text=' '.join(text)
  return text

# %%
st='This is my words in the form of steming alji ljieeodjsla, if of is.'
print(clean_text(st))
# Out:
# word form steme alji ljieeodjsla

# %%
df['Statement']=df['Statement'].apply(clean_text)
df['Statement']
# Out:
# 0        prais india 's aarogya setu app say help ident...
# 1        delhi deputi us secretari state stephen biegun...
# 2        lac tension china 's strategi behind deliber f...
# 3        india sign 250 document space cooper 59 countr...
# 4           tamil nadu chief minist 's mother pass away 93
#                                ...
# 56709         fact check bruce lee play ping-pong nunchaku
# 56710             fact check japan construct bridg 24 hour
# 56711    fact check viral video mexico earthquak 2 year...
# 56712    fact check ballet perform chines coupl goe vir...
# 56713    fact check littl boy cross jordan alon lose fa...
# Name: Statement, Length: 56711, dtype: object

# %%
X=df['Statement']
Y=df['Label']

# %%
X.shape,Y.shape
print(Y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 56709    0
# 56710    0
# 56711    0
# 56712    0
# 56713    0
# Name: Label, Length: 56711, dtype: int64

# %%
tfidf=TfidfVectorizer()
tfidf.fit(X)
# Out:
# TfidfVectorizer()

# %%
X=tfidf.transform(X)
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 548480 stored elements and shape (56711, 30061)>
#   Coords	Values
#   (0, 441)	0.17894941768765626
#   (0, 1986)	0.4019970932502017
#   (0, 3075)	0.30972100909696143
#   (0, 6194)	0.4465912732373539
#   (0, 6872)	0.16041867514017766
#   (0, 11480)	0.256672061708042
#   (0, 12041)	0.3553478335237228
#   (0, 12314)	0.158625030085614
#   (0, 19138)	0.3085456812060765
#   (0, 21637)	0.1680882286372054
#   (0, 22008)	0.3801339271463009
#   (1, 4399)	0.38157318182041317
#   (1, 7549)	0.15160805092154747
#   (1, 7670)	0.2611165107951592
#   (1, 12376)	0.27660812420908476
#   (1, 17902)	0.4228575766033054
#   (1, 18356)	0.38842458445421985
#   (1, 18723)	0.29631905902993666
#   (1, 21828)	0.2668669946643195
#   (1, 23262)	0.18278390012818918
#   (1, 23321)	0.3555256287936962
#   (1, 25666)	0.19547231738247922
#   (2, 4099)	0.2945047717477699
#   (2, 5907)	0.25989693592993757
#   (2, 7562)	0.44754881631293814
#   :	:
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=42,test_size=0.3)

# %%
X_train.shape
# Out:
# (39697, 30061)

# %%
X_test.shape
# Out:
# (17014, 30061)

# %%
for name,model in models.items():
  model.fit(X_train,Y_train)
  print(f'{name}\n Training Score {model.score(X_train,Y_train)}\n Testing Score {model.score(X_test,Y_test)}')
# Out:
# LogisticRegression
#  Training Score 0.9469481321006625
#  Testing Score 0.9368755142823557
# DecisionTreeClassifier
#  Training Score 0.9942061112930448
#  Testing Score 0.9138944398730457
# RandomForestClassifier
#  Training Score 0.9942061112930448
#  Testing Score 0.9401669213588809
# MultinomialNB
#  Training Score 0.9441771418495101
#  Testing Score 0.9270012930527801
# SVC
#  Training Score 0.9803259692168174
#  Testing Score 0.9464558598800987
# KNeighborsClassifier
#  Training Score 0.9290626495704966
#  Testing Score 0.8854472787116492

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=model.predict(X_test)
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90      5645
#            1       0.92      0.99      0.95     11369
#
#     accuracy                           0.94     17014
#    macro avg       0.95      0.91      0.93     17014
# weighted avg       0.94      0.94      0.94     17014

# %%
import pickle
pickle.dump(model,open('Fake_Indian_news_detector_model.pkl','wb'))
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(clean_text,open('clean_text.pkl','wb'))
